# %% [markdown]
# Pandas:
#
# -used for data manipulation
#
# -create dataframes from excel,csv,txt,DBs
#
# -Dataframe (rows and columns readable by python)
#
# -data cleaning by dropping or replacing with mean
#
# -visualize the data

# %%
import pandas as pd

# %% [markdown]
# importing files
#
# -for csv and txt: read_csv("file path")
#
# -for excel:read_excel("file path")

# %%
df=pd.read_csv("/content/database.csv")

# %%
df.head(10)
# Out:
#    Year  Economy         Economy Label Absolute value in thousands  \
# 0  1950        1  Individual economies              NOT APPLICABLE
# 1  1950        4           Afghanistan                    7480.461
# 2  1950        8               Albania                    1252.582
# 3  1950       12               Algeria                    9019.866
# 4  1950       16        American Samoa                      19.032
# 5  1950       20               Andorra                       6.005
# 6  1950       24                Angola                    4478.184
# 7  1950      660              Anguilla                       5.017
# 8  1950       28   Antigua and Barbuda                      45.435
# 9  1950       32             Argentina                   17017.742
#
#   Absolute value in thousands Missing value  \
# 0                            NOT APPLICABLE
# 1                                         0
# 2                                         0
# 3                                         0
# ...

# %%
df.tail(10)
# Out:
#        Year  Economy                                      Economy Label  \
# 31561  2050     1620            LLDCs (Landlocked developing countries)
# 31562  2050     1640  SIDS (Small island developing States) (UN-OHRLLS)
# 31563  2050     2623                    Low-income developing economies
# 31564  2050     2622                 Middle-income developing economies
# 31565  2050     2621                   High-income developing economies
# 31566  2050     2711                                              BRICS
# 31567  2050     3412                            European Union (2020 …)
# 31568  2050     3916                              G20 (Group of Twenty)
# 31569  2050     3919                                 G-77 (Group of 77)
# 31570  2050     3905  OECD (Organisation for Economic Cooperation an...
#
#       Absolute value in thousands Absolute value in thousands Missing value  \
# 31561                  953724.261                                         0
# ...

# %%
dft=pd.read_csv("/content/grades[1].txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dfe=pd.read_excel("/content/diabetes(1).xlsx")

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B>

# %%
print(dft.shape) #get the number of rows and columns
print(dft.shape[0]) #get the number of rows only
print(dft.shape[1]) #get the number of columns only
# Out:
# (16, 6)
# 16
# 6

# %%
print(dft.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade'], dtype='object')

# %% [markdown]
# Accessing Data
#
# -loc - accepts column names and index
#
# iloc - accepts only index

# %%
dft.describe()
# Out:
#             SEM1       SEM2      SEM3
# count  16.000000  16.000000  16.00000
# mean    8.900000   8.912500   8.86875
# std     1.077652   0.589774   1.10497
# min     7.000000   8.000000   7.00000
# 25%     7.700000   8.750000   8.67500
# 50%     9.350000   9.100000   9.25000
# 75%     9.825000   9.150000   9.45000
# max     9.900000  10.000000   9.90000

# %%
print(dft[2:5]) #to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"]) #rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5, :4]) #iloc[row range,column range] =>index
# Out:
#     Names Initials  SEM1  SEM2
# 2  Kissan        V   9.9   9.3
# 3    Mary        N   7.7   8.0
# 4    Jeen        K   9.8   9.1

# %%
dfn=pd.read_csv("/content/grades.csv")

# %%
dfn.isnull() #to view nulls
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum() #to view how many nulls we have per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum() # to view total nulls
# Out:
# 4

# %%
dfc=dfn.dropna() #dropping all the rows with nulls

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5.0)

# %%
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
m=dfn["SEM3"].mean() #cleaning with mean
print(m)
# Out:
# 9.100000000000001

# %%
n=dfn["SEM2"].mean()
print(n)
# Out:
# 9.0

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Columns

# %%
dfc2.rename(columns={"Grade":"GPA"}) #df.rename(columns={old:new})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   9.1   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   9.1   9.1   9.9  A+       1
# 9   Rajini        M   9.1   9.1   9.3   A       0
# 10   Kiran        V   9.1   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
dfc2.rename(columns={"Grade":"GPA"},inplace= True)

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   9.1   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
dfc2["Avg_score"]=(dfc2["SEM1"]+dfc2["SEM2"]+ dfc2["SEM3"])/3 #df["newcol"]=values

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1   B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9  A+       1   9.600000

# %%
dfc2[["SEM1","SEM2"]].plot.line()
# Out:
# <Axes: >

# %%
dfc2[["SEM1","SEM2"]].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
dfc2.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x="Names",y="SEM1",data=dfc2)

# %%
pl=sns.barplot(x="Names",y="SEM1",data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Names")

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# load diabetes as csv
#
# create relplot
#
# create plot with age in x axis and class as columns

# %%
dfc4= pd.read_csv("/content/diabebets.csv")

# %%
dfc4.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
dfc4["index"]=(range(1,769))

# %%
dfc4
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
sns.relplot(
    data=dfc4,
    x="index",y="age",col="class"
)

# %% [markdown]
# seaborn
# inbuilt data set in seaborn
#
# -tips
#
# -dowjones
#
# -FMRI region=brain location
#
# -dots
#
# -health ExP
#
# To load dataset use :load_dataset("dataset names")
#
# hue=different color for different caterogy
#
# style=
#
# color palette=bright,pastel,dark,mutued,color blind,deep

# %%
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dowjones=sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
healthexp=sns.load_dataset("healthexp")

# %%
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
dots=sns.load_dataset("dots")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="smoker"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="time"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="size"
)

# %%
sns.lineplot(
    data=tips,
    x="total_bill",y="tip"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="time",style="day"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="time",style="smoker",palette="pastel"
)

# %%
sns.relplot(
    data=dowjones,
    x="Date",y="Price"
)

# %%
sns.relplot(
    data=dowjones,
    x="Date",y="Price",kind="line"
)

# %%
sns.relplot(
    data=fmri,
    x="timepoint",y="signal"
)

# %%
import seaborn as sns

# %%
sns.catplot(
    data=tips,
    x="total_bill",y="day"
)

# %%
sns.catplot(
    data=tips,
    x="time",y="total_bill"
)

# %%
sns.catplot(
    data=tips,
    x="time",y="total_bill",kind="violin",hue="smoker"
)

# %%
sns.catplot(
    data=tips,
    x="time",y="total_bill",kind="violin"
)

# %%
sns.catplot(
    data=tips,
    x="total_bill",y="day",kind="violin"
)

# %% [markdown]
# linear fit
# lmplot and create a function
#
# -ploting the dataset
#
# -fitting the line
#
# -pedirte

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %%
import pandas as pd
