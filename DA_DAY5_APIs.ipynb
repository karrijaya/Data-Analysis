# %%
import requests

# %%
page=requests.get("https://randomfox.ca/floof")

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/7.jpg","link":"https:\/\/randomfox.ca\/?i=7"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/7.jpg', 'link': 'https://randomfox.ca/?i=7'}

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '47f743cf-82dd-4689-b982-b8c7d50ebe2c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T10:22:34.133Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5416, 'name': 'mzh0zcxv9f', 'symbol': 'muat370hsmd', 'slug': 'ia4lpfrwuhj', 'cmc_rank': 9250, 'num_market_pairs': 8009, 'circulating_supply': 545, 'total_supply': 9134, 'max_supply': 1883, 'infinite_supply': None, 'last_updated': '2024-02-16T10:22:34.132Z', 'date_added': '2024-02-16T10:22:34.132Z', 'tags': ['c44w0vnvp6e', 'ikbhh6vxvjc', 'ra51mundxz', '3mahxbrn4kx', 'ex28dldist8', 'pje7uz9rzch', 'wo86yvpugas', 'jpe0aqhvw8h', 'xvu36najbl', '4w82nyk3vgg'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.4908901078476038, 'volume_24h': 8907, 'volume_change_24h': 0.4193735062082533, 'percent_change_1h': 0.713406112961247, 'percent_change_24h': 0.4338681338928305, 'percent_change_7d': 0.5244431942441523, 'market_cap': 0.11389040409912865, 'market_cap_dominance': 8149, 'fully_diluted_market_cap': 0.31952877169782345, 'last_updated': '2024-02-16T10:22:34.132Z'}}}, {'id': 1909, 'name': 'bcyvj31v0jw', 'symbol': 't6e9qbqpa1m', 'slug': 'q9fal0bs0gf', 'cmc_rank': 5309, 'num_market_pairs': 2437, 'circulating_supply': 5321, 'total_supply': 1908, 'max_supply': 1833, 'infinite_supply': None, 'last_updated': '2024-02-16T10:22:34.132Z', 'date_added': '2024-02-16T10:22:34.132Z', 'tags': ['cvvtiyhzue6', 'yt2tk8vf7mg', '7g5pw7qenri', '1w657hkb967', 'mcxm4iep6wh', '9g8t3wh67h9', '36dn5e8f1oc', 'pc5rb0zt1yk', 'twgnl6f4brs', 'fv9c8lnezbn'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5456956847482721, 'volume_24h': 4288, 'volume_change_24h': 0.8613515174753852, 'percent_change_1h': 0.1874068522558967, 'percent_change_24h': 0.34698768503627986, 'percent_change_7d': 0.5254110031176256, 'market_cap': 0.415142977646346, 'market_cap_dominance': 3094, 'fully_diluted_market_cap': 0.3356016206645789, 'last_updated': '2024-02-16T10:22:34.132Z'}}}, {'id': 538, 'name': 'nqu0vlop2z', 'symbol': 'atuy1t1ms5d', 'slug': '1fumkuka9vj', 'cmc_rank': 952, 'num_market_pairs': 6087, 'circulating_supply': 3400, 'total_supply': 5579, 'max_supply': 7011, 'infinite_supply': None, 'last_updated': '2024-02-16T10:22:34.132Z', 'date_added': '2024-02-16T10:22:34.132Z', 'tags': ['r04q6ufukfm', '7rjdnujajcp', '9uwl42yiezt', 'crw1gvdyplw', 'ka85i3qfig8', 'yxquq0ba1nq', 'apeb6aqgyya', '8bzo0lqiw1', 'gacjhhi9wgq', 'tf43uuwc04'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7295209281855242, 'volume_24h': 7692, 'volume_change_24h': 0.641551715352122, 'percent_change_1h': 0.7619272041427074, 'percent_change_24h': 0.18535271671572517, 'percent_change_7d': 0.07279682106370511, 'market_cap': 0.765298842559847, 'market_cap_dominance': 9396, 'fully_diluted_market_cap': 0.343766739309209, 'last_updated': '2024-02-16T10:22:34.132Z'}}}, {'id': 3280, 'name': 'eh3ah1jgdye', 'symbol': '1kd08emq2q2', 'slug': 'prfj82d3a2', 'cmc_rank': 501, 'num_market_pairs': 9338, 'circulating_supply': 5596, 'total_supply': 2235, 'max_supply': 7995, 'infinite_supply': None, 'last_updated': '2024-02-16T10:22:34.132Z', 'date_added': '2024-02-16T10:22:34.132Z', 'tags': ['kngdlyec0nf', 'sxnoxpx9luf', 'waeh283lww', 'nnf6nbhvjwl', '80l1x98lyqo', 'pjkakwwvdwc', '8wgld856q9', 'rva9zo5wgs', 'lgo3wqtz6cg', 'kyt0hah9qn8'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8615628263066528, 'volume_24h': 3197, 'volume_change_24h': 0.4204914453200592, 'percent_change_1h': 0.29205673221780315, 'percent_change_24h': 0.9652308032239327, 'percent_change_7d': 0.4938859658768002, 'market_cap': 0.8124856085220813, 'market_cap_dominance': 6129, 'fully_diluted_market_cap': 0.8454306775163929, 'last_updated': '2024-02-16T10:22:34.132Z'}}}, {'id': 3777, 'name': 'pl1k3lm9cx', 'symbol':  ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
norm=pd.json_normalize(data["data"])
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  5416   mzh0zcxv9f  muat370hsmd  ia4lpfrwuhj      9250              8009
# 1  1909  bcyvj31v0jw  t6e9qbqpa1m  q9fal0bs0gf      5309              2437
# 2   538   nqu0vlop2z  atuy1t1ms5d  1fumkuka9vj       952              6087
# 3  3280  eh3ah1jgdye  1kd08emq2q2   prfj82d3a2       501              9338
# 4  3777   pl1k3lm9cx  m3wy9o64ngb  qij36h1yjxr      2899               359
# 5  1399   z0yjrc2ejy  4y87wzzwdj3  h8dyd3eaw5q       716              1852
# 6   248  7u4dgyfoxd6   mexygutx0z  7bp6dnmmkma      7874              4517
# 7  3205   x1rqea4jvg  2toys7gjrtc  wmsl8xhd4p9      7670                49
# 8  9626  6a0yxtizlkq   idx70os1lu  5v1v089zerk      3820              7904
# 9   806  26xdqk4x191   l4rvk0e9wa  ck7yz3ztqaa      9643              2467
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                 545          9134        1883            None  ...
# 1                5321          1908        1833            None  ...
# 2                3400          5579        7011            None  ...
# 3                5596          2235        7995            None  ...
# 4                4974          7168        8762            None  ...
# 5                3539          8682        9458            None  ...
# 6                1724          5966        7498            None  ...
# 7                8876          7782        4101            None  ...
# 8                2872          8602        9311            None  ...
# 9                5860          4849        4498            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.490890                 8907                    0.419374
# 1        0.545696                 4288                    0.861352
# 2        0.729521                 7692                    0.641552
# 3        0.861563                 3197                    0.420491
# 4        0.923925                 7364                    0.289363
# 5        0.101115                 1852                    0.786671
# 6        0.699918                 4456                    0.901953
# 7        0.139843                 8437                    0.074838
# 8        0.093143                 6832                    0.576844
# 9        0.432068                 7458                    0.429961
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.713406                     0.433868
# 1                    0.187407                     0.346988
# 2                    0.761927                     0.185353
# 3                    0.292057                     0.965231
# 4                    0.621972                     0.408401
# 5                    0.013399                     0.845933
# 6                    0.494046                     0.945682
# 7                    0.378428                     0.348860
# 8                    0.289800                     0.509671
# 9                    0.945782                     0.400223
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.524443              0.113890
# 1                    0.525411              0.415143
# 2                    0.072797              0.765299
# 3                    0.493886              0.812486
# 4                    0.243049              0.290296
# 5                    0.767705              0.127452
# 6                    0.035283              0.120953
# 7                    0.834600              0.000313
# 8                    0.119833              0.052799
# 9                    0.464028              0.228270
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            8149                            0.319529
# 1                            3094                            0.335602
# 2                            9396                            0.343767
# 3                            6129                            0.845431
# 4                            8114                            0.858235
# 5                            8236                            0.121117
# 6                            4950                            0.415685
# 7                            8381                            0.778203
# 8                             538                            0.053485
# 9                            2952                            0.396272
#
#      quote.USD.last_updated
# 0  2024-02-16T10:22:34.132Z
# 1  2024-02-16T10:22:34.132Z
# 2  2024-02-16T10:22:34.132Z
# 3  2024-02-16T10:22:34.132Z
# 4  2024-02-16T10:22:34.132Z
# 5  2024-02-16T10:22:34.132Z
# 6  2024-02-16T10:22:34.132Z
# 7  2024-02-16T10:22:34.132Z
# 8  2024-02-16T10:22:34.132Z
# 9  2024-02-16T10:22:34.132Z
#
# [10 rows x 26 columns]
